# %%
# Add dependencies
import glob
import pandas as pd

# %%
# glob.glob('data*.csv') - returns List[str]
# pd.read_csv(f) - returns pd.DataFrame()
# for f in glob.glob() - returns a List[DataFrames]
# pd.concat() - returns one pd.DataFrame()
clean_data_ridership = pd.concat([pd.read_csv(f) for f in glob.glob('C:/Users/Magnus/Desktop/Tableau/raw_data/CitiBikeDailyRidershipandMembershipData/*.csv')], ignore_index = True)
clean_data_trip = pd.concat([pd.read_csv(f) for f in glob.glob('C:/Users/Magnus/Desktop/Tableau/raw_data/CitiBikeTripHistories/*.csv')], ignore_index = True)
# Out:
# C:\Users\Magnus\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.

# %%
clean_data_ridership.head()
# Out:
#      Date  Trips over the past 24-hours (midnight to 11:59pm)  \
# 0  1/1/17                                              16009
# 1  1/2/17                                               8921
# 2  1/3/17                                              14198
# 3  1/4/17                                              34039
# 4  1/5/17                                              28393
#
#    Miles traveled today (midnight to 11:59 pm)  \
# 0                                        50761
# 1                                        21545
# 2                                        25879
# 3                                        69966
# 4                                        52446
#
#    Total Annual Members (All Time)  \
# 0                           206624
# 1                           206675
# 2                           206728
# 3                           206778
# 4                           206845
#
#    24-Hour Passes Purchased (midnight to 11:59 pm)  \
# ...

# %%
clean_data_ridership.count()
# Out:
# Date                                                  365
# Trips over the past 24-hours (midnight to 11:59pm)    365
# Miles traveled today (midnight to 11:59 pm)           365
# Total Annual Members (All Time)                       365
# 24-Hour Passes Purchased (midnight to 11:59 pm)       365
# 3-Day Passes Purchased (midnight to 11:59 pm)         365
# dtype: int64

# %%
clean_data_trip.head()
# Out:
#    Bike ID  Birth Year  End Station ID  End Station Latitude  \
# 0  25542.0      1965.0          3165.0             40.775794
# 1  21136.0      1987.0           498.0             40.748549
# 2  18147.0         NaN          3152.0             40.768737
# 3  21211.0         NaN          3152.0             40.768737
# 4  26819.0         NaN          3152.0             40.768737
#
#    End Station Longitude             End Station Name  Gender  \
# 0             -73.976206  Central Park West & W 72 St     2.0
# 1             -73.988084           Broadway & W 32 St     2.0
# 2             -73.961199              3 Ave & E 71 St     0.0
# 3             -73.961199              3 Ave & E 71 St     0.0
# 4             -73.961199              3 Ave & E 71 St     0.0
#
#    Start Station ID  Start Station Latitude  Start Station Longitude  \
# 0            3226.0               40.782750               -73.971370
# 1            3263.0               40.729236               -73.990868
# ...

# %%
# Export to csv
clean_data_ridership.to_csv("clean_data/clean_quarter_data_2017.csv")
clean_data_trip.to_csv("clean_data/clean_data_2017.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-11-4ca8fce599d6> in <module>()
#       1 # Export to csv
# ----> 2 clean_data_ridership.to_csv("clean_data/clean_quarter_data_2017.csv")
#       3 clean_data_trip.to_csv("clean_data/clean_data_2017.csv")
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, tupleize_cols, date_format, doublequote, escapechar, decimal)
#    1743                                  doublequote=doublequote,
#    1744                                  escapechar=escapechar, decimal=decimal)
# -> 1745         formatter.save()
#    1746
#    1747         if path_or_buf is None:
#
# ~\Anaconda3\lib\site-packages\pandas\io\formats\csvs.py in save(self)
# ...
